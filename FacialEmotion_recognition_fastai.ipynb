h" --header="Connection: keep-alive" "https://knsqsq.dm.files.1drv.com/y4mpVVEF9SjFBBhA_GapwrTZafyhjVWB3_ZM-qbXL8_9godP6bUAmnOqTuoOyfKJp5PtP-eFu1wKWdLImcEA9_QUaNn_gtQvpR04HxrogoPmr8hgVTvqWwHuR1eOSqOHkLU49y2nwS8ZOXnpTrF_X6TqpE4dIKxhWePWW73EI-XWunuS4ucxguyXOY7uiwB6mE-?access_token=EwAQA61DBAAUzl/nWKUlBg14ZGcybuC4/OHFdfEAAXyXbR6sR6dWxv4CeccyMQv6NysfR7hHDH/%2bSJdLf48q51tV9ABhgN6RIVC79VHA2cgnvdqA1w%2bqKJVKK9BikK%2bdvPff3fqMpiokJFWLnWLVo82X9QTWJpQ/2XyCiPeaoMrh3j9v%2bB2dE9g/DmqWca095hCDt%%2bDRKnzUIQiA0vKNE0WrCbhLlop7ZuYBR4NYCSuNZwUSiMtTm1nR4CaKjLQgT2jNWwh0abXMfRN5nRKA2dQBeAtVAY3MOYzl0Mo3tReiZUbY3QQLF3boCzzlV3ZHVsrDoKyuqjBdFno2h1E%2bssVZvSWLQ/ov2DYd/wv5XxQz5iYXDi/FlkCKoI7B3nYLQKsOaSaTcHXqym71a3bygtVxvXGV2RW2nn19TqFeJXFOJGYvqqWRQdeLNkYMIki3/vLhWEJUDVQmaUx0k251%2bnWMPJDljygyz0D23sQh9lO4HNPJpzUZRiQ2ORlTUYfVRXfB62S4PkRt2%2bdb0m%2bzIDd7NAuvVcnotr64DJm8gjztXkEnTvghDELRfq9cbsBJj3mTt28B4HUpimTC1/96QYj%2bVBejS7vDi3JpBSnRIg24IMp12IkF0gquJ3nzsuyBhGz0vknlsjtWreQtewfjRI0GNImbmGkLI4GFJjd8TFKQRmkz7Cl8iaTayjYx3z7IQi7QpNgAsVtJWr1Q4CyoVAg%3d%3d" -c -O 'validation.csv'

# %%
#!pip install fastai2

# %% [markdown]
# ## Import fastai Libraries

# %%
from fastai2.vision.all import *
import pandas as pd
import os
from datetime import datetime
import matplotlib.pyplot as plt

# %%
train = pd.read_csv("training.csv")
train.head(20)

# %% [markdown]
# ## Create new column with just filenemes

# %%
train['filename'] = train.apply(lambda row: row.subDirectory_filePath[row["subDirectory_filePath"].find("/") + 1 :], axis = 1)

# %%
train.drop(["subDirectory_filePath"], axis = 1,inplace = True)

# %% [markdown]
# ## Affectnet dataset has 11 classes  defined

# %%
emotional_categories = {0: 'Neutral', 1: 'Happiness', 2: 'Sadness',
                        3: 'Surprise', 4: 'Fear', 5: 'Disgust', 6: 'Anger',
                        7: 'Contempt', 8: 'No-Expression', 9: 'Uncertain',
                        10: 'No-Face'
                       }

# %%
path = Path("FacialEmotion_Images/")

# %% [markdown]
# ## Create Directories for all the Classes

# %%
for i in list(emotional_categories.values()):
    dest = (path/i)
    if not dest.exists():
        dest.mkdir(exist_ok=True)

# %%
# Code to check if it is directory or not 


# source = 'FacialEmotion_Images/'

# files = os.listdir(source)
# for f in files:
#     if os.path.isdir(source + f) == True:  
#         print(f)

# %% [markdown]
# ##  Creating a Subset of 150k from 420k images and move images to respective Class Folders

# %%
# This action should take you more than an hour

start = datetime.now()
print(start)
source = 'FacialEmotion_Images/'

files = os.listdir(source)
for f in files[0:150000]:    
    row = train[train["filename"] == f]    
    if len(row["expression"].values) > 0 :        
        dest = source + emotional_categories[row["expression"].values[0]]
        shutil.move(source+f, dest)
print('Time taken :', datetime.now() - start)

# %% [markdown]
# ## Code to move remaining 250k images to others folder

# %%
# dest = (path/'Others')
# if not dest.exists():
#     dest.mkdir(exist_ok=True)

# %%
# source = 'FacialEmotion_Images/'

# files = os.listdir(source)
# for f in files:
#     if os.path.isdir(source + f) == False:  
#         dest = source + 'Others'
#         shutil.move(source+f, dest)

# %%
# source = 'FacialEmotion_Images/Others'
# shutil.move(source, ".")

# %% [markdown]
# ## Distribution of images for Different Classes

# %%
source = 'FacialEmotion_Images/'
ImageCount_PerClass = {}
for i in list(emotional_categories.values()):
     
    files = os.listdir(source + i)
    ImageCount_PerClass[i] = len(files)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
Classes = list(ImageCount_PerClass.keys())
Count = list(ImageCount_PerClass.values())
ax.bar(Classes,Count)
plt.show()

# %% [markdown]
# ## Multi Label Classification

# %% [markdown]
# ## Get the path of all images

# %%
path = Path("FacialEmotion_Images/")
fns = get_image_files(path)
fns

# %% [markdown]
# ### Check if there are any corrupt images and remove them

# %%
failed = verify_images(fns)
failed

# %%
failed.map(Path.unlink);

# %% [markdown]
# ## Use Data Block api to create train and validation datasets

# %%
#With data block API you can fully customize every stage of the creation of your DataLoaders. 
#What kinds of data we are working with, How to get the list of items,How to label these items,How to create the validation set


emotions = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = emotions.dataloaders(path)

# %%
dls.valid.show_batch(max_n=10, nrows=3)

# %% [markdown]
# ## Train the model using pretrained renet34

# %%
learn = cnn_learner(dls, resnet34, metrics=[error_rate,accuracy])
#learn.fine_tune(4)

# %% [markdown]
# ## used Fitonecycle to get faster convergence

# %%
start = datetime.now()
print(start)
learn.fit_one_cycle(4)

print('Time taken :', datetime.now() - start)

# %% [markdown]
# ## Save the model

# %%
learn.save('stage-1')

# %% [markdown]
# ## Interpret the missclassification classes

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(dls.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('No-Expression', 'Neutral', 1115),
#  ('No-Face', 'Happiness', 769),
#  ('No-Face', 'Neutral', 765),
#  ('No-Expression', 'Happiness', 707),
#  ('Happiness', 'Neutral', 704),
#  ('Sadness', 'Neutral', 701),
#  ('Anger', 'Neutral', 565),
#  ('Neutral', 'Happiness', 559),
#  ('Neutral', 'No-Face', 550),
#  ('Happiness', 'No-Face', 319),
#  ('Surprise', 'Neutral', 317),
#  ('Uncertain', 'Neutral', 300),
#  ('Neutral', 'Anger', 200),
#  ('Uncertain', 'Happiness', 191),
#  ('No-Expression', 'No-Face', 188),
#  ('Anger', 'No-Face', 184),
#  ('No-Expression', 'Anger', 178),
#  ('No-Face', 'Anger', 162),
#  ('Sadness', 'No-Face', 157),
#  ('Surprise', 'Happiness', 157),
#  ('Neutral', 'Sadness', 149),
#  ('Contempt', 'Happiness', 142),
#  ('Sadness', 'Anger', 142),
#  ('No-Expression', 'Sadness', 128),
#  ('No-Face', 'Sadness', 126),
#  ('Sadness', 'Happiness', 117),
#  ('Fear', 'Neutral', 114),
#  ('Uncertain', 'No-Face', 111),
#  ('Anger', 'Sadness', 109),
# ...

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.167764</td>
#       <td>1.131124</td>
#       <td>0.374767</td>
#       <td>0.625233</td>
#       <td>06:36</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=9.999999747378752e-07, lr_steep=3.981071586167673e-06)

# %%
learn.unfreeze()
learn.fit_one_cycle(3, lr_max=slice(1e-5,1e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.188148</td>
#       <td>1.160385</td>
#       <td>0.385080</td>
#       <td>0.614920</td>
#       <td>06:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.088627</td>
#       <td>1.117875</td>
#       <td>0.369135</td>
#       <td>0.630865</td>
#       <td>06:32</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.954830</td>
#       <td>1.134301</td>
#       <td>0.371239</td>
#       <td>0.628761</td>
#       <td>06:31</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Validate Model Accuracy after removing three classes No-expression,No-Face,Uncertain

# %%
#No-Expression,No-Face,Uncertain
source = 'FacialEmotion_Images/No-Expression'
shutil.move(source, ".")
source = 'FacialEmotion_Images/No-Face'
shutil.move(source, ".")
source = 'FacialEmotion_Images/Uncertain'
shutil.move(source, ".")
# Out:
# './Uncertain'

# %%
emotional_categories = {0: 'Neutral', 1: 'Happiness', 2: 'Sadness',
                        3: 'Surprise', 4: 'Fear', 5: 'Disgust', 6: 'Anger',
                        7: 'Contempt'
                       }

# %%
source = 'FacialEmotion_Images/'
ImageCount_PerClass = {}
for i in list(emotional_categories.values()):
     
    files = os.listdir(source + i)
    ImageCount_PerClass[i] = len(files)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,2,1])
Classes = list(ImageCount_PerClass.keys())
Count = list(ImageCount_PerClass.values())
ax.bar(Classes,Count)
plt.show()

# %%
path = Path("FacialEmotion_Images/")
fns = get_image_files(path)
fns
# Out:
# (#102260) [Path('FacialEmotion_Images/Surprise/c81bb37961c846a307afab3958d21ae1b323b04ce502c60305332061.jpg'),Path('FacialEmotion_Images/Surprise/1734ef25d4a425b89098dc695b1c12c82617f5a05cf8011b792991a0.jpg'),Path('FacialEmotion_Images/Surprise/8f9ee8c4cce86ee7f65d306eac2da2cdaca9a4fac3ef3899489cbaf7.jpeg'),Path('FacialEmotion_Images/Surprise/857dd56a2b2fdd207991f83460ec1dbd6714bec1c6ea1047d328de3f.jpg'),Path('FacialEmotion_Images/Surprise/0942c5819f24dbf4a0eb406448e94552da8210c8ff1aa167e9117c5c.jpg'),Path('FacialEmotion_Images/Surprise/44fcf1f865162fec739737d38e0bf8f341ae1a068feb012310abe98c.jpg'),Path('FacialEmotion_Images/Surprise/1fd5d38b97510fb06983d06b890c23298034786cf8672b286d032672.jpg'),Path('FacialEmotion_Images/Surprise/7f1385317b218a00c19348d1af99443a4e70c15e3f5bb8e24552f752.jpg'),Path('FacialEmotion_Images/Surprise/304ee0154f6ad0cc6963c7a23d7fa255f56d969186edfcf1bb8f1242.jpg'),Path('FacialEmotion_Images/Surprise/a0852d0e0a97957dbbc59779857ccc03bc9b7792a0d3b13da80f9849.jp
# ...

# %%
#With data block API you can fully customize every stage of the creation of your DataLoaders. 
#What kinds of data we are working with, How to get the list of items,How to label these items,How to create the validation set


emotions = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = emotions.dataloaders(path)

# %%
dls.valid.show_batch(max_n=10, nrows=3)

# %%
learn = cnn_learner(dls, resnet34, metrics=[error_rate,accuracy])
#learn.fine_tune(4)

# %%
start = datetime.now()
print(start)
learn.fit_one_cycle(4)

print('Time taken :', datetime.now() - start)
# Out:
# 2020-07-19 00:11:45.706273
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.085292</td>
#       <td>0.977452</td>
#       <td>0.336935</td>
#       <td>0.663065</td>
#       <td>04:44</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.881677</td>
#       <td>0.869625</td>
#       <td>0.301926</td>
#       <td>0.698074</td>
#       <td>04:45</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.844256</td>
#       <td>0.824253</td>
#       <td>0.286965</td>
#       <td>0.713035</td>
#       <td>04:45</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.797152</td>
#       <td>0.817975</td>
#       <td>0.282955</td>
#       <td>0.717045</td>
#       <td>04:42</td>
#     </tr>
#   </tbody>
# ...

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(dls.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Sadness', 'Neutral', 797),
#  ('Happiness', 'Neutral', 694),
#  ('Anger', 'Neutral', 672),
#  ('Neutral', 'Happiness', 667),
#  ('Surprise', 'Neutral', 359),
#  ('Neutral', 'Anger', 211),
#  ('Neutral', 'Sadness', 207),
#  ('Surprise', 'Happiness', 190),
#  ('Contempt', 'Happiness', 166),
#  ('Sadness', 'Happiness', 161),
#  ('Sadness', 'Anger', 137),
#  ('Anger', 'Happiness', 129),
#  ('Fear', 'Neutral', 129),
#  ('Fear', 'Surprise', 121),
#  ('Neutral', 'Surprise', 109),
#  ('Anger', 'Sadness', 102),
#  ('Contempt', 'Neutral', 96),
#  ('Disgust', 'Neutral', 85),
#  ('Happiness', 'Surprise', 76),
#  ('Happiness', 'Anger', 72),
#  ('Disgust', 'Anger', 70),
#  ('Fear', 'Sadness', 59),
#  ('Happiness', 'Sadness', 58),
#  ('Disgust', 'Happiness', 49),
#  ('Fear', 'Anger', 44),
#  ('Fear', 'Happiness', 43),
#  ('Sadness', 'Surprise', 43),
#  ('Anger', 'Surprise', 36),
#  ('Surprise', 'Anger', 35),
#  ('Surprise', 'Sadness', 35),
#  ('Surprise', 'Fear', 34),
# ...

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.767026</td>
#       <td>0.737837</td>
#       <td>0.257970</td>
#       <td>0.742030</td>
#       <td>04:46</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=1.318256749982538e-07, lr_steep=3.311311274956097e-06)

# %%
learn.unfreeze()
learn.fit_one_cycle(3, lr_max=slice(1e-7,1e-6))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.793830</td>
#       <td>0.818776</td>
#       <td>0.283591</td>
#       <td>0.716409</td>
#       <td>04:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.786974</td>
#       <td>0.816957</td>
#       <td>0.282124</td>
#       <td>0.717876</td>
#       <td>04:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.779140</td>
#       <td>0.814695</td>
#       <td>0.281831</td>
#       <td>0.718169</td>
#       <td>04:43</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## lets detect faces and eyes using Haarcascades

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
source = 'FacialEmotion_Images/Happiness'

files = os.listdir(source)
print(files[0])
# Out:
# ee3e34511f2f22200933201cd059141a300ecfadb71d648681778756.jpg

# %%
img = cv2.imread('./FacialEmotion_Images/Happiness/ee3e34511f2f22200933201cd059141a300ecfadb71d648681778756.jpg')
img.shape
# Out:
# (188, 188, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (188, 188)

# %%
gray
# Out:
# array([[116, 118, 120, ..., 135, 134, 134],
#        [125, 127, 128, ..., 135, 134, 134],
#        [135, 136, 137, ..., 135, 135, 134],
#        ...,
#        [111, 113, 114, ..., 150, 150, 149],
#        [114, 115, 117, ..., 150, 149, 148],
#        [115, 118, 122, ..., 150, 149, 147]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %% [markdown]
# ## Detect Frontal Face and Eye  using Haarcascades

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 25,  22, 148, 148]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (25, 22, 148, 148)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is not None:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                return roi_color

# %%
original_image = cv2.imread('./FacialEmotion_Images/Happiness/ee3e34511f2f22200933201cd059141a300ecfadb71d648681778756.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./FacialEmotion_Images/Happiness/ee3e34511f2f22200933201cd059141a300ecfadb71d648681778756.jpg')
plt.imshow(cropped_image)

# %%
path_to_data = "./FacialEmotion_Images/"
path_to_cr_data = "./FacialEmotion_Images/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
facial_emotion_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    facial_emotion_name = img_dir.split('/')[-1]
    print(facial_emotion_name)
    
    facial_emotion_file_names_dict[facial_emotion_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + facial_emotion_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = facial_emotion_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            facial_emotion_file_names_dict[facial_emotion_name].append(cropped_file_path)
            count += 1
# Out:
# Surprise
# Generating cropped images in folder:  ./FacialEmotion_Images/cropped/Surprise
# Contempt
# Generating cropped images in folder:  ./FacialEmotion_Images/cropped/Contempt
# Disgust
# Generating cropped images in folder:  ./FacialEmotion_Images/cropped/Disgust
# Fear
# Generating cropped images in folder:  ./FacialEmotion_Images/cropped/Fear
# Happiness
# Generating cropped images in folder:  ./FacialEmotion_Images/cropped/Happiness
# Anger
# Generating cropped images in folder:  ./FacialEmotion_Images/cropped/Anger
# Neutral
# Generating cropped images in folder:  ./FacialEmotion_Images/cropped/Neutral

# %%
cropped_image_dirs = []
facial_emotion_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    facial_emotion_name = img_dir.split('/')[-1]
    print(facial_emotion_name)
    
    facial_emotion_file_names_dict[facial_emotion_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + facial_emotion_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = facial_emotion_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            facial_emotion_file_names_dict[facial_emotion_name].append(cropped_file_path)
            count += 1
# Out:
# Sadness

# %%
path = Path('FacialEmotion_Images/cropped')
fns = get_image_files(path)
fns
# Out:
# (#73671) [Path('FacialEmotion_Images/cropped/Surprise/Surprise1855.png'),Path('FacialEmotion_Images/cropped/Surprise/Surprise3023.png'),Path('FacialEmotion_Images/cropped/Surprise/Surprise2891.png'),Path('FacialEmotion_Images/cropped/Surprise/Surprise1269.png'),Path('FacialEmotion_Images/cropped/Surprise/Surprise1186.png'),Path('FacialEmotion_Images/cropped/Surprise/Surprise204.png'),Path('FacialEmotion_Images/cropped/Surprise/Surprise2416.png'),Path('FacialEmotion_Images/cropped/Surprise/Surprise1210.png'),Path('FacialEmotion_Images/cropped/Surprise/Surprise260.png'),Path('FacialEmotion_Images/cropped/Surprise/Surprise2465.png')...]

# %%
emotions = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = emotions.dataloaders(path)

# %%
dls.valid.show_batch(max_n=10, nrows=3)

# %%
learn = cnn_learner(dls, resnet34, metrics=[error_rate,accuracy])
#learn.fine_tune(4)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.085657</td>
#       <td>0.943868</td>
#       <td>0.324420</td>
#       <td>0.675580</td>
#       <td>08:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.858151</td>
#       <td>0.816924</td>
#       <td>0.277318</td>
#       <td>0.722682</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.799198</td>
#       <td>0.777337</td>
#       <td>0.269852</td>
#       <td>0.730148</td>
#       <td>02:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.782274</td>
#       <td>0.769193</td>
#       <td>0.264015</td>
#       <td>0.735985</td>
#       <td>02:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(dls.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Happiness', 'Neutral', 549),
#  ('Sadness', 'Neutral', 531),
#  ('Neutral', 'Happiness', 477),
#  ('Anger', 'Neutral', 413),
#  ('Surprise', 'Neutral', 275),
#  ('Neutral', 'Anger', 162),
#  ('Neutral', 'Sadness', 132),
#  ('Surprise', 'Happiness', 116),
#  ('Contempt', 'Happiness', 109),
#  ('Fear', 'Neutral', 93),
#  ('Sadness', 'Happiness', 89),
#  ('Contempt', 'Neutral', 86),
#  ('Sadness', 'Anger', 81),
#  ('Anger', 'Happiness', 66),
#  ('Anger', 'Sadness', 66),
#  ('Neutral', 'Surprise', 60),
#  ('Disgust', 'Anger', 55),
#  ('Fear', 'Surprise', 53),
#  ('Disgust', 'Neutral', 51),
#  ('Happiness', 'Surprise', 44),
#  ('Happiness', 'Anger', 43),
#  ('Disgust', 'Happiness', 34),
#  ('Fear', 'Anger', 31),
#  ('Happiness', 'Sadness', 31),
#  ('Fear', 'Sadness', 29),
#  ('Surprise', 'Sadness', 26),
#  ('Surprise', 'Fear', 25),
#  ('Fear', 'Happiness', 22),
#  ('Anger', 'Surprise', 21),
#  ('Surprise', 'Anger', 19),
#  ('Sadness', 'Surprise', 17),
#  ('Disgust', 'Sadness', 14),
# ...

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.873154</td>
#       <td>0.983217</td>
#       <td>0.339826</td>
#       <td>0.660174</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.747989</td>
#       <td>0.701254</td>
#       <td>0.245622</td>
#       <td>0.754378</td>
#       <td>02:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.623756</td>
#       <td>0.667084</td>
#       <td>0.232252</td>
#       <td>0.767748</td>
#       <td>02:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %%
learn.load('stage-1');

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=3.6307807022240014e-06, lr_steep=1.3182567499825382e-06)

# %%
learn.unfreeze()
learn.fit_one_cycle(4, lr_max=slice(1e-4,1e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.803197</td>
#       <td>0.760494</td>
#       <td>0.267069</td>
#       <td>0.732931</td>
#       <td>02:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.714411</td>
#       <td>0.709572</td>
#       <td>0.240736</td>
#       <td>0.759264</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.576643</td>
#       <td>0.677882</td>
#       <td>0.231234</td>
#       <td>0.768766</td>
#       <td>02:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.437946</td>
#       <td>0.726587</td>
#       <td>0.233202</td>
#       <td>0.766798</td>
#       <td>02:35</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 76% is the  best accuracy we have achieved so far

# %%
learn.export()
